# %% [markdown]
# # Homework 4 - Applied ML
#
# ### Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Read the data

# %%
path = "./lalonde.csv"
df = pd.read_csv(path)
df.head()
# Out:
#      id  treat  age  educ  black  hispan  married  nodegree  re74  re75  \
# 0  NSW1      1   37    11      1       0        1         1   0.0   0.0
# 1  NSW2      1   22     9      0       1        0         1   0.0   0.0
# 2  NSW3      1   30    12      1       0        0         0   0.0   0.0
# 3  NSW4      1   27    11      1       0        0         1   0.0   0.0
# 4  NSW5      1   33     8      1       0        0         1   0.0   0.0
#
#          re78
# 0   9930.0460
# 1   3595.8940
# 2  24909.4500
# 3   7506.1460
# 4    289.7899

# %% [markdown]
# ## Question 1

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True, figsize=(8,3))
sns.distplot(df[df.treat == 1]['re78'], ax=ax1)
sns.distplot(df[df.treat == 0]['re78'], ax=ax2)

# %% [markdown]
# ## Question 2

# %%
features = set(df).difference(set(['id', 'treat', 're78']))

for feature in features:
    fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True, figsize=(8,3))
    sns.distplot(df[df.treat == 1][feature], kde=False, ax=ax1)
    sns.distplot(df[df.treat == 0][feature], kde=False, ax=ax2)
